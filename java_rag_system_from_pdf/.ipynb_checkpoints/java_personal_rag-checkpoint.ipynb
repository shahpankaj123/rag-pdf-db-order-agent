# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
file_path = "javanotes5.pdf"

# %%
loader = PyPDFLoader(file_path)
pages = loader.load()

len(pages)
# Out:
# 699

# %%
pages[0].page_content[0:500]
# Out:
# 'Introduction to Programming Using Java\nVersion 5.0, December 2006\n(Version 5.0.2, with minor corrections, November 2007)\nDavid J. Eck\nHobart and William Smith Colleges'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1200,
    chunk_overlap=300,
    separators= ["\n\n","\n","."," "]
)

chunks = text_splitter.split_documents(pages)

print(f"Number of chunks: {len(chunks)}")
print(chunks[0].page_content)
# Out:
# Number of chunks: 2279
# Introduction to Programming Using Java
# Version 5.0, December 2006
# (Version 5.0.2, with minor corrections, November 2007)
# David J. Eck
# Hobart and William Smith Colleges

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|████████████████████████████████████████████████████████████████████████| 103/103 [00:00<00:00, 7106.88it/s]

# %%
from langchain_chroma import Chroma

vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory="./chroma_db"
)

# %%
print(vectorstore._collection.count())
# Out:
# 2279

# %%
retriever = vectorstore.as_retriever(search_type="similarity",search_kwargs={"k": 3})

# %%
import getpass
import os

if "groq_open_api_key" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
# Out:
# Enter your Groq API key:  ········

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="qwen/qwen3-32b",
    temperature=0.8,
    max_tokens=None,
    reasoning_format="parsed",
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
def fetch_doc(question):
    docs = retriever.invoke(question)
    return "\n\n----\n\n".join(doc.page_content for doc in docs)

# %%
from langchain_core.prompts import ChatPromptTemplate

messages = ChatPromptTemplate.from_messages([
    (
        "system",
        """You are an expert Java instructor and mentor.

Your role is to teach Java programming concepts clearly and step-by-step.
Explain topics in a simple, beginner-friendly way with real-world examples.

Rules:
- Always explain like a teacher guiding a student
- Start from basics and gradually move to advanced concepts
- Provide Java code examples when needed
- Keep explanations clear, structured, and practical
- If a question is unclear, ask a clarifying question first

Context:
{context}

Answer:
"""
    ),
    ("human", "{question}")
])

# %%
from langchain_core.runnables import RunnableLambda

chain = (
    RunnableLambda(lambda q: {
        "question": q,
        "context": fetch_doc(q)
    })
    | messages
    | llm
)

# %%
response = chain.invoke("What is JDK?")
print(response.content)
# Out:
# The **JDK (Java Development Kit)** is the essential toolkit for building, running, and managing Java programs. Let me explain it step by step in simple terms:
#
# ---
#
# ### **What is the JDK?**
# Think of the JDK as your "toolkit" for creating and running Java programs. It includes:
# 1. **Java Compiler (`javac`)**: Converts your Java code (`MyProgram.java`) into machine-readable bytecode (`MyProgram.class`).
# 2. **Java Runtime Environment (JRE)**: Includes the Java Virtual Machine (JVM) to run Java programs.
# 3. **Development Tools**: Debuggers, documentation tools, and utilities for managing Java projects.
# 4. **Libraries**: Pre-written code (like `TextIO.java` in your book) that you can use in your programs.
#
# ---
#
# ### **Why is the JDK Needed?**
# - If you **only** have the **JRE**, you can *run* Java apps (like games or appslets) but **cannot create** your own programs.
# - The **JDK** is for **developers** who want to write, compile, and test Java code.
#
# ---
#
# ### **Key Components of the JDK**
# 1. **`javac`** (Java Compiler):
#    Converts Java source code to `.class` files.
#    Example:
#    ```bash
#    javac MyProgram.java  # Compiles your code
#    ```
# 2. **`java`** (Java Runtime):
#    Runs compiled Java programs.
#    Example:
#    ```bash
#    java MyProgram  # Runs the program
#    ```
# 3. **`javadoc`**: Generates API documentation from your code comments.
# 4. **`jar`**: Packages your code into a single archive file.
#
# ---
#
# ### **How to Check if the JDK is Installed**
# 1. Open a **command-line interface** (Terminal on Mac/Linux, Command Prompt on Windows).
# 2. Run these commands:
#    ```bash
#    java -version    # Should show Java version (e.g., Java 17)
#    javac -version   # Should show Java Compiler version
#    ```
#    - If `javac` is not found, the JDK is not installed (you only have the JRE).
#    - If `java` works but `javac` fails, you need to install the JDK.
#
# ---
#
# ### **Where to Download the JDK**
# - **Oracle JDK**: [https://www.oracle.com/java/technologies/javase-downloads.html](https://www.oracle.com/java/technologies/javase-downloads.html) (Free for personal use).
# - **OpenJDK**: Open-source alternatives like [Adoptium](https://adoptium.net/) or [Amazon Corretto](https://aws.amazon.com/corretto/).
#
# Choose the version that matches your operating system (Windows, Linux, or macOS).
#
# ---
#
# ### **Example Workflow with the JDK**
# 1. **Write a Java file** (`Hello.java`):
#    ```java
#    public class Hello {
#        public static void main(String[] args) {
#            System.out.println("Hello, World!");
#        }
#    }
#    ```
# 2. **Compile** it with `javac`:
#    ```bash
#    javac Hello.java  # Creates Hello.class
#    ```
# 3. **Run** it with `java`:
#    ```bash
#    java Hello  # Outputs: Hello, World!
#    ```
#
# ---
#
# ### **Quick Summary**
# | Tool      | Purpose                          | Needed For?              |
# |----------|-----------------------------------|---------------------------|
# | `javac`  | Compiles Java code to bytecode    | Writing and building apps |
# | `java`   | Runs compiled Java programs       | Testing and execution     |
# | JRE      | Runs Java apps but not compile   | Users (not developers)    |
# | JDK      | Full development toolset          | Developers                |
#
# If you're learning Java, always install the **JDK**, not just the JRE. Let me know if you need help installing or testing it! 😊

# %%
response = chain.invoke("What is throws keyboard? and difference between throws and throw?")
print(response.content)
# Out:
# Let's explore the `throws` keyword and how it differs from `throw` in Java. I'll explain each concept with examples and clear comparisons.
#
# ---
#
# ### **1. `throws` Keyword**
# Used in **method declarations** to **declare** which exceptions a method might throw.
# - **Purpose**: Tells the caller, "Be prepared to handle these exceptions."
# - **Used for**: Checked exceptions (mandatory declaration) and optionally for unchecked exceptions.
#
# **Example**:
# ```java
# public static void readFile(String filename) throws IOException {
#     // Code that might throw IOException
#     FileReader file = new FileReader(filename); // If file not found, IOException is thrown
# }
# ```
# - Here, `readFile()` is saying: *"I might throw an `IOException`, so the caller must handle it."*
#
# ---
#
# ### **2. `throw` Keyword**
# Used in **method body** to **explicitly throw** an exception.
# - **Purpose**: To force an exception when a specific condition occurs.
# - **Used for**: Any exception object (checked, unchecked, or errors).
#
# **Example**:
# ```java
# public static void validateAge(int age) {
#     if (age < 0) {
#         throw new IllegalArgumentException("Age cannot be negative!");
#     }
# }
# ```
# - Here, if `age` is invalid, we **create and throw** an `IllegalArgumentException`.
#
# ---
#
# ### **Key Differences**
#
# | Feature                 | `throws`                                | `throw`                                  |
# |-------------------------|------------------------------------------|------------------------------------------|
# | **Where used**          | Method declaration                     | Inside method body                       |
# | **Purpose**             | Declare exceptions a method **might** throw | Explicitly **throw** an exception        |
# | **Syntax**              | `throws ExceptionType1, ExceptionType2`| `throw ExceptionObject`                  |
# | **Number of exceptions**| Can declare multiple exceptions        | Can throw only one exception at a time   |
# | **Exception type**      | Works for **checked and unchecked**    | Works for **any Throwable**              |
#
# ---
#
# ### **Example Combining Both**
# ```java
# public static void divide(int a, int b) throws ArithmeticException {
#     if (b == 0) {
#         throw new ArithmeticException("Cannot divide by zero!");
#     }
#     System.out.println(a / b);
# }
# ```
# - `throws` declares that the method **might** throw an `ArithmeticException`.
# - `throw` is used **inside the method** to trigger the exception when `b == 0`.
#
# ---
#
# ### **When to Use Each**
# - Use `throws` when **declaring** a method that could propagate exceptions it doesn't handle.
# - Use `throw` when you **want to explicitly trigger** an exception in code (e.g., invalid input).
#
# ---
#
# ### **Common Mistakes**
# 1. ❌ Using `throws` inside a method body (invalid).
#    ✅ `throws` belongs in the method signature.
# 2. ❌ Throwing a checked exception without `throws` or `try-catch`.
#    ✅ Always handle or declare for checked exceptions.
#
# ---
#
# ### **Summary**
# - `**throws**` is for **declaring** potential exceptions in a method.
# - `**throw**` is for **triggering** an exception explicitly in code.
#
# Let me know if you'd like to see a real-world example or further clarification! 😊
